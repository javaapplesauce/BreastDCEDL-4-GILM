# %% [markdown]
# # SPY1 - Read medical data
# ## Harmonize I-SPY-1 medical data into BreastDCEDL
# ### Author: Itamar Barnea
# ### Date: 2025-03-15

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/naomifridman/BreastDCEDL/blob/main/ISPY1/spy1_metadata.ipynb)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline
import pydicom

# %%
# Check if running in Google Colab

if 'google.colab' in str(get_ipython()):
    print("Running in Google Colab")
    # Clone the repository
    # !git clone https://github.com/naomifridman/BreastDCEDL.git
    # !pip install pydicom

    # Change to the repository directory
    os.chdir('/content/BreastDCEDL')
    
    base_path='/content/BreastDCEDL/SPY1'

# %%
    # Base path of your the nifti data
    base_path="G:\\My Drive\\breast_mri"
    nifti_path= {'spy2':os.path.join(base_path,"SPY2","vis1","dce"),
                        'spy1':os.path.join(base_path,"SPY1","vis1","dce"),
                        'duke':os.path.join(base_path,"DUKE","dce")}

    mask_path={'spy2':os.path.join(base_path,"SPY2","vis1","mask"),
                    'spy1':os.path.join(base_path,"SPY1","vis1","mask"),
                    'duke':os.path.join(base_path,"DUKE","mask")}

# %%
import os, sys
sys.path.append(os.path.abspath(os.path.join('.',  '../utils')))

import data_utils as ds

ds.setup_paths(base_path, nifti_path, mask_path)
# Out:
# {'spy2': 'G:\\My Drive\\breast_mri\\SPY2\\vis1\\dce', 'spy1': 'G:\\My Drive\\breast_mri\\SPY1\\vis1\\dce', 'duke': 'G:\\My Drive\\breast_mri\\DUKE\\dce'} {'spy2': 'G:\\My Drive\\breast_mri\\SPY2\\vis1\\mask', 'spy1': 'G:\\My Drive\\breast_mri\\SPY1\\vis1\\mask', 'duke': 'G:\\My Drive\\breast_mri\\DUKE\\mask'}

# %%
base_path="SPY1"

# %%
dname='./TCIA_metadata/I-SPY-1-All-Patient-Clinical-and-Outcome-Data.xlsx'

# %%
import pandas as pd
import numpy as np

# Read the Excel sheets
def merge_ispy_data(df_clinical, df_outcomes):
    # Read clinical data sheet

    
    # Merge the dataframes on subject ID
    df_merged = pd.merge(df_clinical, df_outcomes, on='SUBJECTID', how='left')
    
    # Rename columns for clarity
    df_merged = df_merged.rename(columns={
        'SUBJECTID': 'pid',
        'age': 'age',
        'race_id': 'race',
        'ERpos': 'ER',
        'PgRpos': 'PR', 
        'HR Pos': 'HR',
        'Her2MostPos': 'HER2',
        'HR_HER2_CATEGORY': 'hr_her2_category',
        'HR_HER2_STATUS': 'HR_HER2_STATUS',
        'BilateralCa': 'bilateral',
        'Laterality': 'laterality',
        'MRI LD Baseline': 'MRI_LD_Baseline',
        'MRI LD 1-3dAC': 'early_treatment_mriLD',
        'MRI LD InterReg': 'interreg_mriLD', 
        'MRI LD PreSurg': 'presurg_mriLD',
        'sstat': 'survival_status',
        'survDtD2 (tx)': 'survival_days',
        'RFS': 'rfs_days',
        'rfs_ind': 'rfs_indicator',
        'PCR': 'pCR',
        'RCBClass': 'rcb_class'
    })
    
    # Select and order columns
    columns = [
        'pid', 'age', 'race', 
        'ER', 'PR', 'HR', 'HER2',
        'hr_her2_category', 'HR_HER2_STATUS', 'bilateral', 'laterality',
        'MRI_LD_Baseline', 'early_treatment_mriLD', 'interreg_mriLD', 'presurg_mriLD',
        'survival_status', 'survival_days', 'rfs_days', 'rfs_indicator',
        'pCR', 'rcb_class'
    ]
    
    df_final = df_merged[columns]
    
    # Print summary
    print(f"Data saved successfully. Total patients: {len(df_final)}")
    print("\nColumns in dataset:")
    for col in df_final.columns:
        print(f"- {col}")
        
    return df_final

# Execute the function
df_clinical = pd.read_excel(dname, sheet_name='TCIA Patient Clinical Subset')
    
    # Read outcomes data sheet
df_outcomes = pd.read_excel(dname, sheet_name='TCIA Outcomes Subset')
df_med = merge_ispy_data(df_clinical, df_outcomes)
# Out:
# Data saved successfully. Total patients: 221
#
# Columns in dataset:
# - pid
# - age
# - race
# - ER
# - PR
# - HR
# - HER2
# - hr_her2_category
# - HR_HER2_STATUS
# - bilateral
# - laterality
# - MRI_LD_Baseline
# - early_treatment_mriLD
# - interreg_mriLD
# - presurg_mriLD
# - survival_status
# - survival_days
# - rfs_days
# - rfs_indicator
# - pCR
# - rcb_class

# %%
df_clinical
# Out:
#      SUBJECTID DataExtractDt    age  race_id  ERpos  PgRpos  HR Pos  \
# 0         1001    2009-09-03  38.73        1    1.0     0.0     1.0
# 1         1002    2009-09-03  37.79        1    1.0     1.0     1.0
# 2         1003    2009-09-03  49.83        1    1.0     1.0     1.0
# 3         1004    2009-09-03  48.28        1    0.0     0.0     0.0
# 4         1005    2009-09-03  45.80        1    1.0     1.0     1.0
# ..         ...           ...    ...      ...    ...     ...     ...
# 216       1235    2009-09-03  64.06        1    0.0     0.0     0.0
# 217       1236    2009-09-03  38.61        3    0.0     1.0     1.0
# 218       1237    2009-09-03  46.46        1    1.0     1.0     1.0
# 219       1238    2009-09-03  59.05        3    1.0     1.0     1.0
# 220       1239    2009-09-03  48.57        4    1.0     1.0     1.0
#
#      Her2MostPos  HR_HER2_CATEGORY HR_HER2_STATUS  BilateralCa  Laterality  \
# 0            0.0               1.0   HRposHER2neg            0           1
# 1            0.0               1.0   HRposHER2neg            0           2
# 2            0.0               1.0   HRposHER2neg            0           1
# 3            0.0               3.0      TripleNeg            0           1
# 4            0.0               1.0   HRposHER2neg            0           1
# ..           ...               ...            ...          ...         ...
# 216          1.0               2.0        HER2pos            0           2
# 217          0.0               1.0   HRposHER2neg            0           2
# 218          1.0               2.0        HER2pos            0           2
# 219          1.0               2.0        HER2pos            0           2
# 220          0.0               1.0   HRposHER2neg            0           1
#
#      MRI LD Baseline  MRI LD 1-3dAC  MRI LD InterReg  MRI LD PreSurg
# 0               88.0           78.0             30.0            14.0
# 1               29.0           26.0             66.0            16.0
# 2               50.0           64.0             54.0            46.0
# 3               91.0           90.0             99.0            43.0
# 4               98.0          109.0             60.0            42.0
# ..               ...            ...              ...             ...
# 216             52.0           50.0             28.0             0.0
# 217             51.0           52.0             35.0            23.0
# 218             60.0           60.0             37.0            36.0
# 219             48.0            NaN              NaN             NaN
# 220             74.0           63.0             12.0            10.0
#
# [221 rows x 16 columns]

# %%
df_outcomes
# Out:
#      SUBJECTID DataExtractDt  sstat  survDtD2 (tx)   RFS  rfs_ind  PCR  \
# 0         1001    2009-09-03      8           1264   751        1  0.0
# 1         1002    2009-09-03      8           1155  1043        1  0.0
# 2         1003    2009-09-03      7           2387  2387        0  0.0
# 3         1004    2009-09-03      7           2436  2436        0  0.0
# 4         1005    2009-09-03      7           2220  2520        0  0.0
# ..         ...           ...    ...            ...   ...      ...  ...
# 216       1235    2009-09-03      7           1026  1026        0  1.0
# 217       1236    2009-09-03      8            832   510        1  0.0
# 218       1237    2009-09-03      7           1031  1031        0  0.0
# 219       1238    2009-09-03      7           1248  1248        0  0.0
# 220       1239    2009-09-03      7           1155  1155        0  0.0
#
#      RCBClass
# 0         2.0
# 1         3.0
# 2         3.0
# 3         NaN
# 4         NaN
# ..        ...
# 216       0.0
# 217       3.0
# 218       2.0
# 219       NaN
# 220       1.0
#
# [221 rows x 8 columns]

# %%
df_med.head()
# Out:
#     pid    age  race   ER   PR   HR  HER2  hr_her2_category HR_HER2_STATUS  \
# 0  1001  38.73     1  1.0  0.0  1.0   0.0               1.0   HRposHER2neg
# 1  1002  37.79     1  1.0  1.0  1.0   0.0               1.0   HRposHER2neg
# 2  1003  49.83     1  1.0  1.0  1.0   0.0               1.0   HRposHER2neg
# 3  1004  48.28     1  0.0  0.0  0.0   0.0               3.0      TripleNeg
# 4  1005  45.80     1  1.0  1.0  1.0   0.0               1.0   HRposHER2neg
#
#    bilateral  ...  MRI_LD_Baseline  early_treatment_mriLD  interreg_mriLD  \
# 0          0  ...             88.0                   78.0            30.0
# 1          0  ...             29.0                   26.0            66.0
# 2          0  ...             50.0                   64.0            54.0
# 3          0  ...             91.0                   90.0            99.0
# 4          0  ...             98.0                  109.0            60.0
#
#    presurg_mriLD  survival_status  survival_days  rfs_days  rfs_indicator  \
# 0           14.0                8           1264       751              1
# 1           16.0                8           1155      1043              1
# 2           46.0                7           2387      2387              0
# 3           43.0                7           2436      2436              0
# 4           42.0                7           2220      2520              0
#
#    pCR  rcb_class
# 0  0.0        2.0
# 1  0.0        3.0
# 2  0.0        3.0
# 3  0.0        NaN
# 4  0.0        NaN
#
# [5 rows x 21 columns]

# %%
df_med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pid                    221 non-null    int64
#  1   age                    221 non-null    float64
#  2   race                   221 non-null    int64
#  3   ER                     219 non-null    float64
#  4   PR                     219 non-null    float64
#  5   HR                     219 non-null    float64
#  6   HER2                   216 non-null    float64
#  7   hr_her2_category       216 non-null    float64
#  8   HR_HER2_STATUS         216 non-null    object
#  9   bilateral              221 non-null    int64
#  10  laterality             221 non-null    int64
#  11  MRI_LD_Baseline        219 non-null    float64
#  12  early_treatment_mriLD  210 non-null    float64
#  13  interreg_mriLD         202 non-null    float64
#  14  presurg_mriLD          208 non-null    float64
#  15  survival_status        221 non-null    int64
#  16  survival_days          221 non-null    int64
#  17  rfs_days               221 non-null    int64
#  18  rfs_indicator          221 non-null    int64
#  19  pCR                    215 non-null    float64
#  20  rcb_class              201 non-null    float64
# dtypes: float64(12), int64(8), object(1)
# memory usage: 36.4+ KB

# %%
df_med.HR_HER2_STATUS.value_counts()
# Out:
# HR_HER2_STATUS
# HRposHER2neg    96
# HER2pos         67
# TripleNeg       53
# Name: count, dtype: int64

# %%
df_med.race.value_counts()
# Out:
# race
# 1     165
# 3      42
# 4       9
# 0       2
# 50      2
# 5       1
# Name: count, dtype: int64

# %%
df_med['race_white']=np.where(df_med.race==1, 1, 0)
df_med['race_black']=np.where(df_med.race==3, 1, 0)

# %%
df_med.columns
# Out:
# Index(['pid', 'age', 'race', 'ER', 'PR', 'HR', 'HER2', 'hr_her2_category',
#        'HR_HER2_STATUS', 'bilateral', 'laterality', 'MRI_LD_Baseline',
#        'early_treatment_mriLD', 'interreg_mriLD', 'presurg_mriLD',
#        'survival_status', 'survival_days', 'rfs_days', 'rfs_indicator', 'pCR',
#        'rcb_class', 'race_white', 'race_black'],
#       dtype='object')

# %%
df_med[['pid', 'pCR', 'age',  'race_white', 'race_black',
        'ER', 'PR', 'HR', 'HER2', 'HR_HER2_STATUS',
       'bilateral']].to_csv('BreastDCEDL_spy1_metadata.csv', index = False)
df_med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pid                    221 non-null    int64
#  1   age                    221 non-null    float64
#  2   race                   221 non-null    int64
#  3   ER                     219 non-null    float64
#  4   PR                     219 non-null    float64
#  5   HR                     219 non-null    float64
#  6   HER2                   216 non-null    float64
#  7   hr_her2_category       216 non-null    float64
#  8   HR_HER2_STATUS         216 non-null    object
#  9   bilateral              221 non-null    int64
#  10  laterality             221 non-null    int64
#  11  MRI_LD_Baseline        219 non-null    float64
#  12  early_treatment_mriLD  210 non-null    float64
#  13  interreg_mriLD         202 non-null    float64
#  14  presurg_mriLD          208 non-null    float64
#  15  survival_status        221 non-null    int64
#  16  survival_days          221 non-null    int64
#  17  rfs_days               221 non-null    int64
#  18  rfs_indicator          221 non-null    int64
#  19  pCR                    215 non-null    float64
#  20  rcb_class              201 non-null    float64
#  21  race_white             221 non-null    int32
#  22  race_black             221 non-null    int32
# dtypes: float64(12), int32(2), int64(8), object(1)
# memory usage: 38.1+ KB

# %%
df_med['pid']=df_med.pid.apply(lambda x:'ISPY1_'+str(x))
df_med.head()
# Out:
#           pid    age  race   ER   PR   HR  HER2  hr_her2_category  \
# 0  ISPY1_1001  38.73     1  1.0  0.0  1.0   0.0               1.0
# 1  ISPY1_1002  37.79     1  1.0  1.0  1.0   0.0               1.0
# 2  ISPY1_1003  49.83     1  1.0  1.0  1.0   0.0               1.0
# 3  ISPY1_1004  48.28     1  0.0  0.0  0.0   0.0               3.0
# 4  ISPY1_1005  45.80     1  1.0  1.0  1.0   0.0               1.0
#
#   HR_HER2_STATUS  bilateral  ...  interreg_mriLD  presurg_mriLD  \
# 0   HRposHER2neg          0  ...            30.0           14.0
# 1   HRposHER2neg          0  ...            66.0           16.0
# 2   HRposHER2neg          0  ...            54.0           46.0
# 3      TripleNeg          0  ...            99.0           43.0
# 4   HRposHER2neg          0  ...            60.0           42.0
#
#    survival_status  survival_days  rfs_days  rfs_indicator  pCR  rcb_class  \
# 0                8           1264       751              1  0.0        2.0
# 1                8           1155      1043              1  0.0        3.0
# 2                7           2387      2387              0  0.0        3.0
# 3                7           2436      2436              0  0.0        NaN
# 4                7           2220      2520              0  0.0        NaN
#
#    race_white  race_black
# 0           1           0
# 1           1           0
# 2           1           0
# 3           1           0
# 4           1           0
#
# [5 rows x 23 columns]

# %%
pids_med=list(set(df_med.pid))
len(pids_med)
# Out:
# 221

# %%
df_med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pid                    221 non-null    object
#  1   age                    221 non-null    float64
#  2   race                   221 non-null    int64
#  3   ER                     219 non-null    float64
#  4   PR                     219 non-null    float64
#  5   HR                     219 non-null    float64
#  6   HER2                   216 non-null    float64
#  7   hr_her2_category       216 non-null    float64
#  8   HR_HER2_STATUS         216 non-null    object
#  9   bilateral              221 non-null    int64
#  10  laterality             221 non-null    int64
#  11  MRI_LD_Baseline        219 non-null    float64
#  12  early_treatment_mriLD  210 non-null    float64
#  13  interreg_mriLD         202 non-null    float64
#  14  presurg_mriLD          208 non-null    float64
#  15  survival_status        221 non-null    int64
#  16  survival_days          221 non-null    int64
#  17  rfs_days               221 non-null    int64
#  18  rfs_indicator          221 non-null    int64
#  19  pCR                    215 non-null    float64
#  20  rcb_class              201 non-null    float64
#  21  race_white             221 non-null    int32
#  22  race_black             221 non-null    int32
# dtypes: float64(12), int32(2), int64(7), object(2)
# memory usage: 38.1+ KB

# %%
df_med.columns
# Out:
# Index(['pid', 'age', 'race', 'ER', 'PR', 'HR', 'HER2', 'hr_her2_category',
#        'HR_HER2_STATUS', 'bilateral', 'laterality', 'MRI_LD_Baseline',
#        'early_treatment_mriLD', 'interreg_mriLD', 'presurg_mriLD',
#        'survival_status', 'survival_days', 'rfs_days', 'rfs_indicator', 'pCR',
#        'rcb_class', 'race_white', 'race_black'],
#       dtype='object')

# %%
### check Null pCR

# %%
df_med.survival_status=df_med.survival_status.map({7:'alive',8:'dead',9:'lost'})

# %%
df_med.rfs_indicator=df_med.rfs_indicator.map({0:'free of event at last check',1:'Event occurred'})

# %%
df_med[df_med.pCR.isna()][['pid','MRI_LD_Baseline',
       'early_treatment_mriLD', 'interreg_mriLD', 'presurg_mriLD','survival_status', 'survival_days', 'rfs_days', 'rfs_indicator']]
# Out:
#             pid  MRI_LD_Baseline  early_treatment_mriLD  interreg_mriLD  \
# 20   ISPY1_1025             47.0                   45.0            42.0
# 30   ISPY1_1035            100.0                   90.0            60.0
# 58   ISPY1_1064             70.0                   67.0            47.0
# 61   ISPY1_1067             77.0                   60.0             0.0
# 108  ISPY1_1120             74.0                   48.0            39.0
# 186  ISPY1_1205             75.0                   70.0            47.0
#
#      presurg_mriLD survival_status  survival_days  rfs_days  \
# 20            42.0            dead            718       718
# 30            41.0           alive           2240       729
# 58            30.0           alive           2063       369
# 61             NaN            dead           1044       469
# 108            NaN            lost            530       530
# 186           35.0            lost            185       185
#
#                    rfs_indicator
# 20                Event occurred
# 30                Event occurred
# 58                Event occurred
# 61                Event occurred
# 108  free of event at last check
# 186  free of event at last check

# %%
# dead or event occure and large presurg_mriLD
df_med.at[20,'pCR']=0
df_med.at[30,'pCR']=0
df_med.at[58,'pCR']=0

# %%
# dead or event occure and large presurg_mriLD
df_med.at[186,'pCR']=0

# %%
df_med.to_csv('BreastDCEDL_spy1_metadata.csv', index = False)

# %%
df_voi = pd.read_csv('./TCIA_metadata/subject_voi_values.csv')
df_voi=df_voi.rename(columns={'Subject ID':'pid'})

# %%
df_voi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pid                220 non-null    object
#  1   voi_start_x        173 non-null    float64
#  2   voi_start_y        173 non-null    float64
#  3   voi_start_z        173 non-null    float64
#  4   voi_end_x          173 non-null    float64
#  5   voi_end_y          173 non-null    float64
#  6   voi_end_z          173 non-null    float64
#  7   Number of Entries  220 non-null    int64
#  8   VOI Width          173 non-null    float64
#  9   VOI Height         173 non-null    float64
#  10  VOI Depth          173 non-null    float64
#  11  VOI Volume         173 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 20.8+ KB

# %%
df_med = df_med.merge(df_voi, on="pid", how="left")
df_med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pid                    221 non-null    object
#  1   age                    221 non-null    float64
#  2   race                   221 non-null    int64
#  3   ER                     219 non-null    float64
#  4   PR                     219 non-null    float64
#  5   HR                     219 non-null    float64
#  6   HER2                   216 non-null    float64
#  7   hr_her2_category       216 non-null    float64
#  8   HR_HER2_STATUS         216 non-null    object
#  9   bilateral              221 non-null    int64
#  10  laterality             221 non-null    int64
#  11  MRI_LD_Baseline        219 non-null    float64
#  12  early_treatment_mriLD  210 non-null    float64
#  13  interreg_mriLD         202 non-null    float64
#  14  presurg_mriLD          208 non-null    float64
#  15  survival_status        221 non-null    object
#  16  survival_days          221 non-null    int64
#  17  rfs_days               221 non-null    int64
#  18  rfs_indicator          221 non-null    object
#  19  pCR                    219 non-null    float64
#  20  rcb_class              201 non-null    float64
#  21  race_white             221 non-null    int32
#  22  race_black             221 non-null    int32
#  23  voi_start_x            173 non-null    float64
#  24  voi_start_y            173 non-null    float64
#  25  voi_start_z            173 non-null    float64
#  26  voi_end_x              173 non-null    float64
#  27  voi_end_y              173 non-null    float64
#  28  voi_end_z              173 non-null    float64
#  29  Number of Entries      219 non-null    float64
#  30  VOI Width              173 non-null    float64
#  31  VOI Height             173 non-null    float64
#  32  VOI Depth              173 non-null    float64
#  33  VOI Volume             173 non-null    float64
# dtypes: float64(23), int32(2), int64(5), object(4)
# memory usage: 57.1+ KB

# %% [markdown]
# RCB class refers to Residual Cancer Burden (RCB) classification, which is used to assess the amount of remaining cancer after neoadjuvant therapy (treatment given before surgery) in breast cancer patients. The classification system helps predict prognosis and survival outcomes.
# RCB is determined based on factors like:
# - Tumor size and cellularity in the breast
# - Number of affected lymph nodes
# - Extent of metastasis in the largest lymph node
#
# The classification includes:
# - RCB-0: Pathologic complete response (no residual cancer)
# - RCB-I: Minimal residual disease
# - RCB-II: Moderate residual disease
# - RCB-III: Extensive residual disease
#
# This system is widely used in clinical settings to guide treatment decisions and

# %%
df_med.columns
# Out:
# Index(['pid', 'age', 'race', 'ER', 'PR', 'HR', 'HER2', 'hr_her2_category',
#        'HR_HER2_STATUS', 'bilateral', 'laterality', 'MRI_LD_Baseline',
#        'early_treatment_mriLD', 'interreg_mriLD', 'presurg_mriLD',
#        'survival_status', 'survival_days', 'rfs_days', 'rfs_indicator', 'pCR',
#        'rcb_class', 'race_white', 'race_black', 'voi_start_x', 'voi_start_y',
#        'voi_start_z', 'voi_end_x', 'voi_end_y', 'voi_end_z',
#        'Number of Entries', 'VOI Width', 'VOI Height', 'VOI Depth',
#        'VOI Volume'],
#       dtype='object')

# %%
df_med = df_med[['pid', 'age',  'ER', 'PR', 'HR', 'HER2', 
       'HR_HER2_STATUS', 'bilateral',  'MRI_LD_Baseline',
       
        'pCR',
       'rcb_class', 'race_white', 'race_black', 'voi_start_x', 'voi_start_y',
       'voi_start_z', 'voi_end_x', 'voi_end_y', 'voi_end_z',
        'VOI Width', 'VOI Height', 'VOI Depth',
       'VOI Volume']]

# %%
df_med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pid              221 non-null    object
#  1   age              221 non-null    float64
#  2   ER               219 non-null    float64
#  3   PR               219 non-null    float64
#  4   HR               219 non-null    float64
#  5   HER2             216 non-null    float64
#  6   HR_HER2_STATUS   216 non-null    object
#  7   bilateral        221 non-null    int64
#  8   MRI_LD_Baseline  219 non-null    float64
#  9   pCR              219 non-null    float64
#  10  rcb_class        201 non-null    float64
#  11  race_white       221 non-null    int32
#  12  race_black       221 non-null    int32
#  13  voi_start_x      173 non-null    float64
#  14  voi_start_y      173 non-null    float64
#  15  voi_start_z      173 non-null    float64
#  16  voi_end_x        173 non-null    float64
#  17  voi_end_y        173 non-null    float64
#  18  voi_end_z        173 non-null    float64
#  19  VOI Width        173 non-null    float64
#  20  VOI Height       173 non-null    float64
#  21  VOI Depth        173 non-null    float64
#  22  VOI Volume       173 non-null    float64
# dtypes: float64(18), int32(2), int64(1), object(2)
# memory usage: 38.1+ KB

# %%
df_med.to_csv('BreastDCEDL_spy1_metadata.csv', index = False)

# %%
df = df_med

# %%
df['HRposHER2neg'] = np.where( (df.HR == 1) & (df.HER2 == 0),1, 0)
df['HRposHER2neg'] = np.where((df.HR.isna()) | (df.HER2.isna()) , None, df['HRposHER2neg'])
df['HRposHER2neg'].value_counts(dropna=False)
# Out:
# HRposHER2neg
# 0       120
# 1        96
# None      5
# Name: count, dtype: int64

# %%
df['TripleNeg'] = np.where( (df.HR == 0) & (df.HER2 == 0),1, 0)
df['TripleNeg'] = np.where((df.HR.isna()) | (df.HER2.isna()) , None, df['TripleNeg'])
df['TripleNeg'].value_counts(dropna=False)
# Out:
# TripleNeg
# 0       163
# 1        53
# None      5
# Name: count, dtype: int64

# %%
df['HER2pos'] = df['HER2']
df['HER2pos'].value_counts(dropna=False)
# Out:
# HER2pos
# 0.0    149
# 1.0     67
# NaN      5
# Name: count, dtype: int64

# %%
df = df_med.rename(columns={'race_a':'race_white', 'race_b':'race_black'})

# %%
df['HER2pos']=df['HER2']
df['HRposHER2neg']=np.where((df['HR']==1) & (df['HER2']==0),1,0)
df['HRposHER2neg']=np.where((df['HR'].isna()) | (df['HER2'].isna()),None,df['HRposHER2neg'])
df['TripleNeg']=np.where((df['HR']==0) & (df['HER2']==0),1,0)
df['TripleNeg']=np.where((df['HR'].isna()) | (df['HER2'].isna()),None,df['TripleNeg'])

# %%
df['dataset']='duke'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pid              221 non-null    object
#  1   age              221 non-null    float64
#  2   ER               219 non-null    float64
#  3   PR               219 non-null    float64
#  4   HR               219 non-null    float64
#  5   HER2             216 non-null    float64
#  6   HR_HER2_STATUS   216 non-null    object
#  7   bilateral        221 non-null    int64
#  8   MRI_LD_Baseline  219 non-null    float64
#  9   pCR              219 non-null    float64
#  10  rcb_class        201 non-null    float64
#  11  race_white       221 non-null    int32
#  12  race_black       221 non-null    int32
#  13  voi_start_x      173 non-null    float64
#  14  voi_start_y      173 non-null    float64
#  15  voi_start_z      173 non-null    float64
#  16  voi_end_x        173 non-null    float64
#  17  voi_end_y        173 non-null    float64
#  18  voi_end_z        173 non-null    float64
#  19  VOI Width        173 non-null    float64
#  20  VOI Height       173 non-null    float64
#  21  VOI Depth        173 non-null    float64
#  22  VOI Volume       173 non-null    float64
#  23  HRposHER2neg     216 non-null    object
#  24  TripleNeg        216 non-null    object
#  25  HER2pos          216 non-null    float64
#  26  dataset          221 non-null    object
# dtypes: float64(19), int32(2), int64(1), object(5)
# memory usage: 45.0+ KB

# %%
df['HR_HER2_STATUS']=np.where(df['HRposHER2neg']==1, 'HRposHER2neg', 0)
df['HR_HER2_STATUS']=np.where(df['HER2pos']==1, 'HER2pos', df['HR_HER2_STATUS'])
df['HR_HER2_STATUS']=np.where(df['TripleNeg']==1, 'TripleNeg', df['HR_HER2_STATUS'])
df['HR_HER2_STATUS']=np.where(df['HR'].isna(), None, df['HR_HER2_STATUS'])
df['HR_HER2_STATUS']=np.where(df['HER2'].isna(), None, df['HR_HER2_STATUS'])

# %%
df.to_csv('BreastDCEDL_spy1_metadata.csv', index = False)

# %% [markdown]
# ## Add info from Dicom

# %%
df_dicom = pd.read_csv('spy1_data_from_dicom.csv')
df_dicom.columns
# Out:
# Index(['pid', 'spt_res', 'xy_spacing', 'slice_thick', 'later', 'tcol',
#        'max_dcm0', 'max_dcm1', 'max_dcm2', 'mask_sum', 'is_mask', 'pre',
#        'post_early', 'post_late', 'n_times', 'mask_start', 'mask_end', 'sraw',
#        'eraw', 'scol', 'ecol', 'n_z', 'n_xy'],
#       dtype='object')

# %%
df = df.merge(df_dicom[["pid","pre","post_early", "post_late", 
                  'xy_spacing', 'slice_thick', 'later',
                        'n_times', 'mask_start', 'mask_end', 'sraw', 'eraw',
       'scol', 'ecol', 'n_z', 'n_xy'
                 ]], on="pid", how="left");

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pid              221 non-null    object
#  1   age              221 non-null    float64
#  2   ER               219 non-null    float64
#  3   PR               219 non-null    float64
#  4   HR               219 non-null    float64
#  5   HER2             216 non-null    float64
#  6   HR_HER2_STATUS   216 non-null    object
#  7   bilateral        221 non-null    int64
#  8   MRI_LD_Baseline  219 non-null    float64
#  9   pCR              219 non-null    float64
#  10  rcb_class        201 non-null    float64
#  11  race_white       221 non-null    int32
#  12  race_black       221 non-null    int32
#  13  voi_start_x      173 non-null    float64
#  14  voi_start_y      173 non-null    float64
#  15  voi_start_z      173 non-null    float64
#  16  voi_end_x        173 non-null    float64
#  17  voi_end_y        173 non-null    float64
#  18  voi_end_z        173 non-null    float64
#  19  VOI Width        173 non-null    float64
#  20  VOI Height       173 non-null    float64
#  21  VOI Depth        173 non-null    float64
#  22  VOI Volume       173 non-null    float64
#  23  HRposHER2neg     216 non-null    object
#  24  TripleNeg        216 non-null    object
#  25  HER2pos          216 non-null    float64
#  26  dataset          221 non-null    object
#  27  pre              187 non-null    float64
#  28  post_early       187 non-null    float64
#  29  post_late        187 non-null    float64
#  30  xy_spacing       202 non-null    float64
#  31  slice_thick      202 non-null    float64
#  32  later            198 non-null    object
#  33  n_times          172 non-null    float64
#  34  mask_start       172 non-null    float64
#  35  mask_end         172 non-null    float64
#  36  sraw             172 non-null    float64
#  37  eraw             172 non-null    float64
#  38  scol             172 non-null    float64
#  39  ecol             172 non-null    float64
#  40  n_z              172 non-null    float64
#  41  n_xy             172 non-null    float64
# dtypes: float64(33), int32(2), int64(1), object(6)
# memory usage: 70.9+ KB

# %%
df['is_mask']=0

# %%
for i,row in df.iterrows():
    pid=row['pid']
    m=ds.get_nifti_mask(pid)
    if m is not None:
        df.at[i,'is_mask']=1
        df.at[i,'tum_vol'] = (m/m.max()).sum()*row['xy_spacing']*row['xy_spacing']*row['slice_thick']/1000.
# Out:
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files
# no nifti files

# %%
df['is_mask'].value_counts()
# Out:
# is_mask
# 1    172
# 0     49
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 44 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pid              221 non-null    object
#  1   age              221 non-null    float64
#  2   ER               219 non-null    float64
#  3   PR               219 non-null    float64
#  4   HR               219 non-null    float64
#  5   HER2             216 non-null    float64
#  6   HR_HER2_STATUS   216 non-null    object
#  7   bilateral        221 non-null    int64
#  8   MRI_LD_Baseline  219 non-null    float64
#  9   pCR              219 non-null    float64
#  10  rcb_class        201 non-null    float64
#  11  race_white       221 non-null    int32
#  12  race_black       221 non-null    int32
#  13  voi_start_x      173 non-null    float64
#  14  voi_start_y      173 non-null    float64
#  15  voi_start_z      173 non-null    float64
#  16  voi_end_x        173 non-null    float64
#  17  voi_end_y        173 non-null    float64
#  18  voi_end_z        173 non-null    float64
#  19  VOI Width        173 non-null    float64
#  20  VOI Height       173 non-null    float64
#  21  VOI Depth        173 non-null    float64
#  22  VOI Volume       173 non-null    float64
#  23  HRposHER2neg     216 non-null    object
#  24  TripleNeg        216 non-null    object
#  25  HER2pos          216 non-null    float64
#  26  dataset          221 non-null    object
#  27  pre              187 non-null    float64
#  28  post_early       187 non-null    float64
#  29  post_late        187 non-null    float64
#  30  xy_spacing       202 non-null    float64
#  31  slice_thick      202 non-null    float64
#  32  later            198 non-null    object
#  33  n_times          172 non-null    float64
#  34  mask_start       172 non-null    float64
#  35  mask_end         172 non-null    float64
#  36  sraw             172 non-null    float64
#  37  eraw             172 non-null    float64
#  38  scol             172 non-null    float64
#  39  ecol             172 non-null    float64
#  40  n_z              172 non-null    float64
#  41  n_xy             172 non-null    float64
#  42  is_mask          221 non-null    int64
#  43  tum_vol          172 non-null    float64
# dtypes: float64(34), int32(2), int64(2), object(6)
# memory usage: 74.4+ KB

# %%
df.dataset='spy1'

# %%
df.to_csv('BreastDCEDL_spy1_metadata.csv', index = False)
